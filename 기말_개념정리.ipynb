# %% [markdown]
# -----
#
# ### 1\. 순차적 자료구조 (Sequential Structures)
#
# **핵심 개념:** 메모리의 연속된 공간에 데이터를 저장하며, 인덱스(Index)를 통해 빠르게 접근합니다.
#
# | 자료구조 | 핵심 개념 | 연산 | 시간 복잡도 | 비고 |
# | :--- | :--- | :--- | :--- | :--- |
# | **배열 / 리스트**<br>(Array / Python List) | [cite_start]• 연속된 메모리 공간<br>• 동적 배열(Dynamic Array): 크기 자동 조절 [cite: 435] | `A[i]` (접근/수정) | [cite_start]**$O(1)$** [cite: 366] | 인덱스로 즉시 접근 |
# | | | `append(x)` (끝 삽입) | [cite_start]**Amortized $O(1)$** [cite: 460] | 재할당(Resizing) 시 $O(n)$ |
# | | | `pop()` (끝 삭제) | [cite_start]**Amortized $O(1)$** [cite: 462] | |
# | | | `insert(i, x)` (중간 삽입) | [cite_start]**$O(n)$** [cite: 465] | $i$ 뒤의 원소들을 이동해야 함 |
# | | | `pop(i)` / `remove(x)` | [cite_start]**$O(n)$** [cite: 463] | 삭제 후 빈칸 메우기 위해 이동 |
# | | | `search(x)` / `x in A` | [cite_start]**$O(n)$** [cite: 472] | 선형 탐색 (Linear Scan) |
# | **스택**<br>(Stack) | [cite_start]• **LIFO** (Last In First Out)<br>• 파이썬 리스트로 구현 [cite: 607] | `push` (삽입) | [cite_start]**$O(1)$** [cite: 732] | 리스트의 `append` |
# | | | `pop` (삭제) | [cite_start]**$O(1)$** [cite: 732] | 리스트의 `pop` |
# | **큐**<br>(Queue) | [cite_start]• **FIFO** (First In First Out)<br>• `front_idx`를 관리하여 구현 [cite: 742] | `enqueue` (삽입) | [cite_start]**$O(1)$** [cite: 756] | |
# | | | `dequeue` (삭제) | [cite_start]**$O(1)$** [cite: 756] | `pop(0)`을 쓰면 $O(n)$이므로 인덱스 이동으로 구현 |
# | **덱**<br>(Deque) | • 양쪽 끝에서 삽입/삭제 가능<br>• 이중 연결 리스트 기반 | `pushFront/Back` | [cite_start]**$O(1)$** [cite: 786] | |
# | | | `popFront/Back` | [cite_start]**$O(1)$** [cite: 786] | |
#
# -----
#
# ### 2\. 연결 리스트 (Linked Lists)
#
# **핵심 개념:** 노드(Node)들이 링크(Link)를 통해 연결된 구조입니다. 연속된 메모리가 필요 없습니다.
#
# | 자료구조 | 핵심 개념 | 연산 | 시간 복잡도 | 비고 |
# | :--- | :--- | :--- | :--- | :--- |
# | **한방향 연결 리스트**<br>(Singly Linked List) | • `next` 링크만 존재<br>• `head`만 관리 (일반적) | `pushFront` | [cite_start]**$O(1)$** [cite: 1014] | Head 갱신 |
# | | | `pushBack` | [cite_start]**$O(n)$** [cite: 1014] | Tail 포인터 없으면 끝까지 탐색 필요 |
# | | | `popFront` | [cite_start]**$O(1)$** [cite: 1014] | |
# | | | `popBack` | [cite_start]**$O(n)$** [cite: 1014] | Tail의 이전 노드를 찾아야 함 |
# | | | `search(k)` | [cite_start]**$O(n)$** [cite: 1014] | 순차 탐색 |
# | **양방향 연결 리스트**<br>(Doubly Linked List) | [cite_start]• `next`, `prev` 링크 존재<br>• `head`, `tail` (dummy) 관리 [cite: 1051] | `pushFront/Back` | [cite_start]**$O(1)$** [cite: 1114] | 앞뒤 모두 즉시 접근 가능 |
# | | | `popFront/Back` | [cite_start]**$O(1)$** [cite: 1114] | |
# | | | `insertAfter/Before` | [cite_start]**$O(1)$** [cite: 1114] | 해당 노드를 알고 있을 때 |
# | | | `remove(x)` | [cite_start]**$O(1)$** [cite: 1114] | 해당 노드 $x$를 알고 있을 때 |
# | | | `search(k)` | [cite_start]**$O(n)$** [cite: 1114] | |
#
# -----
#
# ### 3\. 해시 테이블 (Hash Table)
#
# **핵심 개념:** 해시 함수 $f(key)$를 통해 저장 위치(Slot)를 계산합니다. **충돌(Collision)** 해결이 핵심입니다.
#
# | 구분 | 핵심 개념 | 연산 | 평균 시간 복잡도 | 최악 시간 복잡도 |
# | :--- | :--- | :--- | :--- | :--- |
# | **해시 테이블**<br>(Hash Table) | [cite_start]• 충돌 해결: **Chaining** (리스트 연결) 또는 **Open Addressing** (Linear Probing 등)<br>• Load Factor ($n/m$) 관리 중요 [cite: 1403] | `set` (삽입/수정) | [cite_start]**$O(1)$** [cite: 1355] | **$O(n)$** (모두 충돌 시) |
# | | | `remove` (삭제) | [cite_start]**$O(1)$** [cite: 1355] | **$O(n)$** |
# | | | `search` (탐색) | [cite_start]**$O(1)$** [cite: 1355] | **$O(n)$** |
#
# > [cite_start]**참고:** Python의 `dict`는 해시 테이블로 구현되어 있으며, 평균적으로 모든 연산이 $O(1)$입니다[cite: 1514].
#
# -----
#
# ### 4\. 트리 (Trees) 및 힙 (Heap)
#
# **핵심 개념:** 계층적 구조입니다. 힙은 완전이진트리 기반의 우선순위 큐이며, 균형 탐색 트리는 높이를 $O(\log n)$으로 유지합니다.
#
# | 자료구조 | 핵심 개념 | 연산 | 시간 복잡도 | 비고 |
# | :--- | :--- | :--- | :--- | :--- |
# | **힙**<br>(Heap) | • 완전이진트리 + 힙 속성 (부모 $\ge$ 자식)<br>• 우선순위 큐 구현에 사용 | `find_max/min` | **$O(1)$** | 루트 노드 확인 |
# | | | `insert` | [cite_start]**$O(\log n)$** [cite: 1583] | `heapify_up` |
# | | | `delete_max/min` | [cite_start]**$O(\log n)$** [cite: 1583] | `heapify_down` |
# | | | `make_heap` | [cite_start]**$O(n)$** [cite: 1584] | 전체 구성 |
# | | | `heap_sort` | [cite_start]**$O(n \log n)$** [cite: 1582] | |
# | **이진탐색트리**<br>(BST) | • 왼쪽 \< 부모 \< 오른쪽<br>• 균형이 안 잡히면 $O(n)$ | `search` / `insert` / `delete` | [cite_start]평균 **$O(\log n)$**<br>최악 **$O(n)$** [cite: 1613] | 편향 트리(Skewed)일 때 최악 |
# | **AVL 트리** | • 균형 조건: 왼쪽/오른쪽 높이 차 $\le 1$<br>• 회전(Rotation)으로 균형 유지 | `search` / `insert` / `delete` | [cite_start]**$O(\log n)$** [cite: 1633] | 항상 균형 유지 ($h \approx 1.44 \log n$) |
# | **Red-Black 트리** | • 노드 색상(Red/Black) 규칙으로 균형 유지<br>• 회전 횟수가 AVL보다 적음 (삭제 시) | `search` / `insert` / `delete` | [cite_start]**$O(\log n)$** [cite: 1633] | 실용적으로 가장 많이 쓰임 (C++, Java 등) |
# | **Splay 트리** | • 접근한 노드를 루트로 이동 (Splaying)<br>• 자주 쓰는 데이터 접근 빠름 | `search` / `insert` / `delete` | [cite_start]**Amortized $O(\log n)$** [cite: 1641] | 최악은 $O(n)$일 수 있으나 평균적으로 빠름 |
#
#   * [cite_start]**트리 연산 회전 횟수 비교 (최악의 경우)** [cite: 1633]
#       * **AVL:** Insert (최대 2회), Delete (최대 $O(\log n)$회)
#       * **Red-Black:** Insert (최대 2회), Delete (최대 3회)
#
# -----
#
# ### 5\. 그래프 (Graph)
#
# **핵심 개념:** 정점(Vertex, Node)과 간선(Edge)으로 구성됩니다. $n$은 노드 수, $m$은 에지 수입니다.
#
# | 표현 방식 / 알고리즘 | 핵심 개념 | 연산 / 특징 | 시간 복잡도 | 공간 복잡도 |
# | :--- | :--- | :--- | :--- | :--- |
# | **인접 행렬**<br>(Adjacency Matrix) | 2차원 배열 `G[u][v]`로 연결 표현 | 두 노드 연결 확인 | [cite_start]**$O(1)$** [cite: 1649] | **$O(n^2)$** |
# | | | 한 노드의 모든 이웃 방문 | [cite_start]**$O(n)$** [cite: 1649] | |
# | **인접 리스트**<br>(Adjacency List) | 연결 리스트로 이웃 노드 저장 | 두 노드 연결 확인 | [cite_start]**$O(\deg(u))$** [cite: 1649] | **$O(n+m)$** |
# | | | 한 노드의 모든 이웃 방문 | [cite_start]**$O(\deg(u))$** [cite: 1649] | 희소 그래프에 유리 |
# | **그래프 순회** | **DFS** (깊이 우선) / **BFS** (너비 우선) | 모든 노드/에지 방문 | [cite_start]**$O(n+m)$** [cite: 1650] | |
# | **최단 경로** | **Dijkstra** (다익스트라) | 단일 출발점 최단 경로 (음수 가중치 X) | [cite_start]**$O(m \log n)$** [cite: 1664] | (Binary Heap 사용 시) |
# | | **Bellman-Ford** | 음수 가중치 허용 | [cite_start]**$O(nm)$** [cite: 1661] | |
#
# -----
#
# 이 표를 바탕으로 각 자료구조의 \*\*최악의 경우(Worst Case)\*\*와 **평균(Average)/상각(Amortized)** 복잡도를 구별하여 암기하시면 시험 대비에 큰 도움이 될 것입니다.

# %% [markdown]
# ---
#
# ### 1. 해시 테이블 (Hash Table) 파트
#
# 이 파트에서는 해시의 충돌 해결 원리를 응용한 알고리즘 문제들이 인터뷰 문제로 다수 소개되었습니다.
#
# #### **🎤 인터뷰 문제 (교재 p.101 ~ p.104)**
# * **문제 1: Uniqueness Problem**
#     * [cite_start]내용: $n$개의 수가 주어졌을 때, 모두 다른 수인지 판별하라. [cite: 1750]
#     * 해법: 정렬($O(n \log n)$) 또는 해시 테이블($O(n)$) 사용.
# * **문제 2: Pair Sum (Two Sum) ⭐ [기출 출제]**
#     * [cite_start]내용: 리스트 $A$와 정수 $K$가 주어질 때, 합이 $K$가 되는 두 수를 찾아라. [cite: 1751]
#     * **[기출 분석]:** **기말고사 4번 문제**가 이 로직을 그대로 코드로 구현한 것입니다. $g(A, K)$ 함수 내 `H.search(K-x)` 부분이 바로 이 알고리즘입니다.
# * **문제 3: Swap Sum**
#     * [cite_start]내용: 두 리스트 $A, B$의 합을 같게 만들기 위해 교환해야 할 두 수를 찾아라. [cite: 1751]
#     * 해법: 차이값($K$)을 계산하여 Pair Sum 문제로 변환.
# * **문제 4: Majority Element**
#     * [cite_start]내용: 리스트에서 절반($n/2$) 넘게 등장하는 수를 찾아라. [cite: 1752]
#     * 해법: 해시 테이블로 카운팅하거나 Boyer-Moore 투표 알고리즘 사용.
# * **문제 5: Longest Equal Number**
#     * [cite_start]내용: 0과 1로 구성된 배열에서 0과 1의 개수가 같은 가장 긴 부분 배열 찾기. [cite: 1753]
#     * 해법: 누적 합의 차이를 해시 테이블의 Key로 사용하여 인덱스 거리 계산.
#
# #### **🚀 심화(Advanced) 내용**
# * [cite_start]**Universal Hashing (c-universal):** 충돌 확률을 수학적으로 보장하는 해시 함수 집합. [cite: 1337]
#     * **[기출 연계]:** 기말고사 **4-B번**에서 c-universal 해시 함수를 사용할 때의 수행 시간 분석을 요구했습니다.
# * [cite_start]**Open Addressing의 성능 분석:** $m \ge 2n$ (테이블 크기가 데이터의 2배 이상)일 때 평균 $O(1)$을 보장한다는 증명 및 클러스터링(Clustering) 현상. [cite: 1488]
# * [cite_start]**Amortized Analysis (Resizing):** 해시 테이블 크기 조정(Doubling/Halving) 시 발생하는 비용을 상각 분석(Charging method)으로 증명. [cite: 1629]
#
# ---
#
# ### 2. 트리(Tree) 및 힙(Heap) 파트
#
# #### **🎤 인터뷰/응용 문제**
# * **순열 복원 (Permutation Restoration):**
#     * [cite_start]내용: 각 수보다 왼쪽에 있는 작은 수의 개수($S_i$)가 주어졌을 때 원본 순열 복원하기. [cite: 1775]
#     * **[기출 연계]:** 기말고사 **7-D번**($k$번째 작은 수 찾기)은 각 노드의 `size`(자손 수)를 이용한다는 점에서 이 문제의 원리(Rank 기반 탐색)와 밀접하게 연관되어 있습니다.
#
# #### **🚀 심화(Advanced) 내용**
# * [cite_start]**Make_Heap의 수행 시간:** 단순히 $O(n \log n)$이 아니라, 엄밀한 분석을 통해 **$O(n)$**임을 증명. [cite: 1764]
# * [cite_start]**Segment Tree (Range Tree) & BIT:** 구간 합(Prefix Sum)이나 구간 업데이트를 $O(\log n)$에 처리하는 고급 자료구조. [cite: 1772, 1779]
#
# ---
#
# ### 3. 이진 탐색 트리(BST) 파트
#
# #### **🎤 인터뷰 문제 (교재 p.149)**
# * **문제 1: BST to Doubly Linked List**
#     * [cite_start]내용: BST를 Inorder 순서에 맞춰 양방향 연결 리스트로 변환하라. [cite: 1798]
# * **문제 2: BST Construction**
#     * [cite_start]내용: 입력된 수열에 따라 BST가 만들어질 때, 동일한 모양의 트리를 만드는 다른 입력 순서의 경우의 수 계산. [cite: 1798]
#
# #### **🚀 심화(Advanced) 내용**
# * [cite_start]**트리 복원:** Preorder, Inorder, Postorder 중 두 가지 순회 결과가 주어졌을 때 원본 트리를 복원하는 방법. [cite: 1785]
#     * **[기출 연계]:** 기말고사 **1-J번**(OX 퀴즈)과 **5번**(Postorder로 트리 복원)에 직접 출제되었습니다.
#
# ---
#
# ### 4. 균형 이진 탐색 트리 (Balanced BST) 파트
#
# 이 부분은 인터뷰 문제보다는 **자료구조 간의 변환**과 **복잡도 증명** 자체가 심화 내용이자 핵심 출제 포인트입니다.
#
# #### **🚀 심화(Advanced) 내용 (기출 집중 출제)**
# * **AVL 트리의 높이 증명:**
#     * [cite_start]내용: 최소 노드 수 $N_h$가 피보나치 수열과 관련됨을 이용해 높이가 $O(\log n)$임을 증명. [cite: 1802]
#     * **[기출 연계]:** 기말고사 **1-I번**과 **8-A번**에서 점화식과 노드 수를 묻는 문제로 출제되었습니다.
# * **Red-Black 트리와 2-3-4 트리의 관계:**
#     * [cite_start]내용: 두 트리가 1:1로 대응된다는 사실과 변환 방법. [cite: 1823]
#     * **[기출 연계]:** 기말고사 **1-Q번**과 **8-E번**에서 변환 과정을 그리라는 문제로 출제되었습니다.
# * **Splay 트리의 Splaying 연산:**
#     * [cite_start]내용: Zig, Zig-Zig, Zig-Zag 회전과 Amortized Analysis 개념. [cite: 1824]
#     * **[기출 연계]:** 기말고사 **1-N번**과 **8-F번**에서 연산 과정을 시뮬레이션하는 문제로 출제되었습니다.
#
# ---
#
# ### 💡 요약: 기출 대비 핵심 가이드
#
# 1.  **해시 테이블:** **Pair Sum(Two Sum)** 코드 로직을 완벽히 이해하고, c-universal 해싱의 시간 복잡도 의미를 파악하세요.
# 2.  **BST 응용:** **Rank(k번째 수) 찾기**와 **순회(Traversal)를 이용한 복원** 과정을 손으로 연습하세요.
# 3.  **균형 트리:** **AVL 최소 노드 점화식**을 암기하고, **AVL $\leftrightarrow$ RB $\leftrightarrow$ 2-3-4 변환** 과정을 그림으로 그릴 수 있어야 합니다. (가장 배점이 큽니다.)

# %% [markdown]
# 제공해주신 기출문제와 교재를 바탕으로 **자료구조 파트별 출제 경향**과 **수업 교재 내 출처**를 상세하게 정리해 드립니다. 이를 통해 기말고사 준비 시 집중해야 할 포인트를 명확히 파악하실 수 있습니다.
#
# ---
#
# ### 1. 알고리즘 분석 (Algorithm Analysis)
# **출제 경향:** 단순 암기보다는 Big-O의 수학적 성질과 코드의 실행 횟수를 분석하는 능력을 평가합니다.
# * **핵심 유형:**
#     * $f(n)$과 $g(n)$의 합/곱에 대한 Big-O 성질 판별 (OX 퀴즈).
#     * 이중 루프(특히 내부 루프가 외부 루프 변수 $i$에 의존하는 경우)의 정확한 수행 횟수 및 시간 복잡도 도출.
# * **기출 문항 및 교재 출처:**
#     * **문항 1-A, 1-B:** 점근적 표기법의 성질 및 로그/지수 함수 복잡도 비교.
#         * [cite_start]👉 **교재 p.25~26:** Big-O 정의 및 함수 증가율 비교 그래프[cite: 476, 517].
#     * **문항 2:** Python 코드(`for i... while j<n`)의 실행 횟수 $T(n)$ 분석.
#         * [cite_start]👉 **교재 p.21:** `arrayMax` 등의 알고리즘 수행 시간 분석 예제[cite: 420].
#
# ### 2. 선형 자료구조 (Stack, Queue, Linked List)
# **출제 경향:** 각 자료구조의 연산 시간 복잡도를 비교하고, 스택의 응용 사례를 실제로 계산할 수 있는지 묻습니다.
# * **핵심 유형:**
#     * 스택을 이용한 후위 표기식(Postfix) 계산.
#     * 단방향 vs 양방향(원형) 연결 리스트의 연산별 시간 복잡도(Big-O) 빈칸 채우기.
# * **기출 문항 및 교재 출처:**
#     * **문항 1-C:** Postfix 수식 계산 결과.
#         * [cite_start]👉 **교재 p.46~48:** Infix → Postfix 변환 및 계산 알고리즘[cite: 841, 874].
#     * **문항 3:** 연결 리스트 연산(`pushBack`, `popFront` 등) 시간 복잡도 표 채우기.
#         * [cite_start]👉 **교재 p.65, 71:** 단방향 및 양방향 연결 리스트의 연산 복잡도 비교표[cite: 1198, 1297].
#
# ### 3. 해시 테이블 (Hash Table)
# **출제 경향:** 해시 충돌 해결 로직을 이해하고, 이를 응용한 알고리즘(Two Sum 등)의 코드 분석 능력을 평가합니다.
# * **핵심 유형:**
#     * 해시를 이용해 배열 내 특정 합을 찾는 알고리즘($K-x$)의 동작 원리 파악.
#     * 충돌 해결 전략(Open Addressing vs Chaining)의 차이 이해.
# * **기출 문항 및 교재 출처:**
#     * **문항 4:** 해시 테이블을 사용한 `g(A, K)` 함수 분석 (Two Sum 문제 변형).
#         * [cite_start]👉 **교재 p.102:** 인터뷰 문제 2 - Pair Sum (해시를 이용한 $O(n)$ 풀이)[cite: 1751].
#
# ### 4. 힙 (Heap)
# **출제 경향:** 힙의 생성 원리와 삽입/삭제 시 발생하는 구조적 변화를 직접 시뮬레이션할 수 있어야 합니다.
# * **핵심 유형:**
#     * 배열 상태에서 `make_heap` 수행 후의 결과 쓰기.
#     * `insert` 연산 시 `heapify_up` 과정의 코드 빈칸 채우기 및 배열 변화 추적.
# * **기출 문항 및 교재 출처:**
#     * **문항 6:** `make_heap` 결과, `heapify_up` 코드 구현, `insert` 시뮬레이션.
#         * [cite_start]👉 **교재 p.114:** `make_heap`의 과정과 그림[cite: 1764].
#         * [cite_start]👉 **교재 p.116~117:** `heapify_up` 및 `insert` 파이썬 코드[cite: 1766].
#
# ### 5. 이진 탐색 트리 (BST)
# **출제 경향:** 트리의 순회(Traversal) 원리를 역이용하거나, 삽입/삭제 로직을 구현하는 문제가 출제됩니다.
# * **핵심 유형:**
#     * Postorder 결과를 보고 Preorder 유추 및 트리 그리기.
#     * BST `insert` 함수의 파이썬 코드 구현 (빈칸 채우기).
#     * `deleteByCopying` vs `deleteByMerging`의 삭제 결과 차이 그리기.
#     * 서브트리 크기(`size`)를 이용해 k번째 작은 수 찾기.
# * **기출 문항 및 교재 출처:**
#     * **문항 5:** 순회(Traversal) 결과를 이용한 트리 복원.
#         * [cite_start]👉 **교재 p.136:** Preorder/Inorder를 이용한 트리 복원 원리[cite: 1785].
#     * **문항 7:** BST `insert` 코드, 삭제 연산 그림 그리기, k번째 수 찾기.
#         * [cite_start]👉 **교재 p.143:** `insert` 함수 코드[cite: 1792].
#         * [cite_start]👉 **교재 p.145~147:** `delete` 연산(`Copying`, `Merging`)의 도식화[cite: 1795].
#         * [cite_start]👉 **교재 p.148:** 순열 복원 문제 등 서브트리 크기 활용 응용[cite: 1776].
#
# ### 6. 균형 이진 탐색 트리 (Balanced BST)
# **출제 경향:** **가장 난이도가 높고 비중이 큽니다.** 여러 균형 트리의 변환 관계와 회전(Rotation)을 완벽히 이해해야 합니다.
# * **핵심 유형:**
#     * AVL 트리의 최소 노드 수 점화식 및 높이 계산.
#     * 회전(Right/Left Rotation) 후의 트리 모양 그리기.
#     * **통합 문제:** AVL 트리에 노드 삽입 → Red-Black 트리로 색칠 → 2-3-4 트리로 변환 → Splay 트리 연산 수행.
# * **기출 문항 및 교재 출처:**
#     * **문항 1-G, H, I, K, L, M, N, P, Q:** 균형 트리들의 높이, 회전 수, 색상 규칙 등 이론 점검.
#         * [cite_start]👉 **교재 p.153:** AVL 높이 및 점화식[cite: 1802].
#         * [cite_start]👉 **교재 p.167:** AVL/RB 회전 횟수 비교표[cite: 1816].
#     * **문항 8:** AVL 회전, 삽입, 삭제 및 RB/2-3-4/Splay 변환 시뮬레이션.
#         * [cite_start]👉 **교재 p.150:** 회전(Rotation) 기본 원리 및 그림[cite: 1799].
#         * [cite_start]👉 **교재 p.174:** RB 트리와 2-3-4 트리의 1:1 대응 관계 그림[cite: 1823].
#         * [cite_start]👉 **교재 p.175:** Splay 트리의 Zig, Zig-Zig, Zig-Zag 연산[cite: 1824].
#
# ### 7. 그래프 (Graph)
# **출제 경향:** 그래프의 표현 방식에 따른 효율성 차이를 묻는 기초적인 문제가 출제됩니다.
# * **핵심 유형:**
#     * 인접 행렬 vs 인접 리스트의 공간 복잡도 및 특정 연산(에지 존재 확인) 시간 복잡도 비교.
# * **기출 문항 및 교재 출처:**
#     * **문항 1-R:** 인접 행렬/리스트의 Big-O 비교 (OX 퀴즈).
#         * [cite_start]👉 **교재 p.183:** 표현법에 따른 연산 시간/공간 복잡도 비교표[cite: 1832].
#
# ---
#
# **🎓 총평 및 학습 조언:**
# 시험 문제는 교재의 **그림(동작 과정)**과 **파이썬 코드**를 정확히 이해하고 있는지 확인하는 데 중점을 두고 있습니다. 특히 **AVL, Red-Black, 2-3-4 트리 간의 변환 관계(교재 p.174)**는 반드시 손으로 그려보며 익히시기 바랍니다.
